# %%
# %pip install flask
# Out:
# ...
#
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------- ----------------------------- 1/4 [itsdangerous]
#    ------------------------------ --------- 3/4 [flask]
#    ------------------------------ --------- 3/4 [flask]
#    ------------------------------ --------- 3/4 [flask]
#    ---------------------------------------- 4/4 [flask]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
